# %% [markdown]
# # Titanic Prediction
#
# This is a jupyter notebook that predicts the survival of passengers on titanic. The data source is from Kaggle Competition: https://www.kaggle.com/competitions/titanic

# %% [markdown]
# ## Library Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Input and Benchmarking

# %%
train_data = pd.read_csv('../input/train.csv')
test_data = pd.read_csv('../input/test.csv')

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# From the table above, we can see the basic data type of the features in the data. At the same time, there are missing value in Age, Cabin, Fare which needs more actions in the engineering session.

# %%
train_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
test_data.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# 1  47.0      1      0     363272   7.0000   NaN        S
# 2  62.0      0      0     240276   9.6875   NaN        Q
# 3  27.0      0      0     315154   8.6625   NaN        S
# 4  22.0      1      1    3101298  12.2875   NaN        S
# 5  14.0      0      0       7538   9.2250   NaN        S
# 6  30.0      0      0     330972   7.6292   NaN        Q
# 7  26.0      1      1     248738  29.0000   NaN        S
# 8  18.0      0      0       2657   7.2292   NaN        C
# 9  21.0      2      0  A/4 48871  24.1500   NaN        S

# %% [markdown]
# ### Benchmarking Model

# %%
def benchmark(X_input):

    #Features dropped in the benchmark model:
    X_input = X_input.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'])
    
    #The missing value in Fare has been filled:
    X_input['Fare'].fillna(X_input['Fare'].mean(), inplace=True)
    
    #The missing value in Age in filled with mean:
    X_input['Age'].fillna(X_input['Age'].mean(), inplace=True)
    
    #Sex has been turned into one-hot format:
    X_input = pd.get_dummies(X_input, columns=['Sex'], drop_first=True)
    
    #The missing value in Embarked has been filled by the most frequent value:
    most_frequent_embarked = X_input['Embarked'].mode()[0]
    X_input['Embarked'].fillna(most_frequent_embarked, inplace=True)
    X_input = pd.get_dummies(X_input, columns=['Embarked'], drop_first=True)    
    
    return(X_input)

# %%
y_train = train_data['Survived']

X_Base_train=benchmark(train_data)
X_Base_train=X_Base_train.drop(columns=['Survived'])
X_Base_test=benchmark(test_data)

print("This is the result of benchmark model:")
benchmark_models,benchmark_result=train_RF(X_Base_train,y_train)
# Out:
# This is the result of benchmark model:
#     mean_test_score  std_test_score  \
# 49         0.831429        0.016338
# 62         0.831429        0.016355
# 48         0.831419        0.018701
# 91         0.831409        0.021711
# 38         0.831409        0.022606
#
#                                                params  rank_test_score
# 49  {'n_estimators': 100, 'min_samples_split': 10,...                1
# 62  {'n_estimators': 150, 'min_samples_split': 2, ...                2
# 48  {'n_estimators': 100, 'min_samples_split': 2, ...                3
# 91  {'n_estimators': 150, 'min_samples_split': 2, ...                4
# 38  {'n_estimators': 100, 'min_samples_split': 5, ...                4

# %% [markdown]
# ## Data Exploration and Feature Engineering

# %% [markdown]
# ### Name - Title

# %%
# We filter out the title from the Name column
train_data['Title'] = train_data['Name'].apply(lambda x: x.split(',')[1].split('.')[0].strip())
test_data['Title'] = test_data['Name'].apply(lambda x: x.split(',')[1].split('.')[0].strip())

# %%
print(train_data['Title'].unique())
print(test_data['Title'].unique())
# Out:
# ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Mme' 'Ms' 'Major' 'Lady'
#  'Sir' 'Mlle' 'Col' 'Capt' 'the Countess' 'Jonkheer']
# ['Mr' 'Mrs' 'Miss' 'Master' 'Ms' 'Col' 'Rev' 'Dr' 'Dona']

# %%
plt.figure(figsize=(10, 6))
train_data['Title'].value_counts().sort_values().plot(kind='barh')
plt.title('Distribution of Titles')
plt.xlabel('Count')
plt.ylabel('Title')
plt.show()

# %% [markdown]
# From the bar chart above, it is noted that the counts for some titles are quite similar, suggesting that these titles might need to be combined.

# %%
def get_titles(title):
    if title in ['Mme', 'Ms', 'Lady', 'Dona']:
        return 'Mrs'
    elif title in ['Mlle', 'the Countess']:
        return 'Miss'
    elif title in ['Capt', 'Col', 'Major', 'Dr', 'Rev', 'Jonkheer', 'Don', 'Sir','Master']:
        return 'Rare'
    else:
        return title

# %%
train_data['Title_Combined'] = train_data['Title'].apply(get_titles)
test_data['Title_Combined'] = test_data['Title'].apply(get_titles)

# %%
X_train = pd.concat([X_Base_train, train_data[['Title_Combined']]], axis=1)
X_train = pd.get_dummies(X_train, columns=['Title_Combined'], drop_first=True)

X_test = pd.concat([X_Base_test, test_data[['Title_Combined']]], axis=1)
X_test = pd.get_dummies(X_test, columns=['Title_Combined'], drop_first=True)

print("This is the new result with title added:")

benchmark_models, benchmark_result = train_RF(X_train, y_train)
# Out:
# This is the new result with title added:
#     mean_test_score  std_test_score  \
# 42         0.835674        0.021151
# 13         0.835625        0.024925
# 91         0.835625        0.022849
# 48         0.834216        0.023726
# 4          0.832857        0.011341
#
#                                                params  rank_test_score
# 42  {'n_estimators': 50, 'min_samples_split': 2, '...                1
# 13  {'n_estimators': 150, 'min_samples_split': 5, ...                2
# 91  {'n_estimators': 150, 'min_samples_split': 2, ...                3
# 48  {'n_estimators': 100, 'min_samples_split': 2, ...                4
# 4   {'n_estimators': 150, 'min_samples_split': 2, ...                5

# %% [markdown]
# ### Age

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_distribution(col_x,key):
 sns.kdeplot(data=train_data[train_data[key] == 1], x=col_x, label='Survived', color='green', fill=True)
 sns.kdeplot(data=train_data[train_data[key] == 0], x=col_x, label='Not Survived', color='red', fill=True)

 plt.xlabel(col_x)
 plt.ylabel('Density')
 plt.title(f'Density Plot of {col_x} by {key}')
 plt.legend()

 plt.show()

# %%
plot_distribution('Age','Survived')

# %% [markdown]
# Remember that we have missing value in the age column, we use the average age of the title group the passenger belongs to to fill the missing value:

# %%
title_age_median_train = train_data.groupby('Title')['Age'].median()
title_age_median_test = test_data.groupby('Title')['Age'].median()

X_train['Age'] = train_data.apply(
    lambda row: title_age_median_train[row['Title']] if pd.isnull(row['Age']) else row['Age'], axis=1
)

X_test['Age'] = test_data.apply(
    lambda row: title_age_median_test[row['Title']] if pd.isnull(row['Age']) else row['Age'], axis=1
)

# %% [markdown]
# From the diagram above we see that child/young people below 16 has a higher survival rate in general, while people have relatively lower survival rate between 20-30. Thus, we split the age data into several bins as below:

# %%
bins_age = [0, 16,20,30,40,60,100] 
labels_age = ['0-16','16-20','20-30','30-40', '40-60','60-100']
X_train['Age_Category'] = pd.cut(X_train['Age'], bins=bins_age, labels=labels_age, right=True)
X_test['Age_Category'] = pd.cut(X_test['Age'], bins=bins_age, labels=labels_age, right=True)

# %%
X_train = pd.get_dummies(X_train, columns=['Age_Category'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['Age_Category'], drop_first=True)

# %%
X_train.drop('Age',axis=1,inplace=True)
X_test.drop('Age',axis=1,inplace=True)

# %% [markdown]
# ## Fare

# %%
X_test['Fare'].fillna(test_data['Fare'].mean(), inplace=True)

# %%
X_train['Fare'].plot(kind='hist', bins=100, edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of Values')
plt.show()

# %% [markdown]
# From the distribution above, we roughly divide the fare into the following groups:

# %%
bins_fare = [0, 10,50, 100, 200,600]
labels_fare = ['0-10','10-50', '50-100','100-200','200+']

X_train['Fare_bin'] = pd.cut(train_data['Fare'], bins=bins_fare, labels=labels_fare, right=False)
X_test['Fare_bin'] = pd.cut(train_data['Fare'], bins=bins_fare, labels=labels_fare, right=False)

# %%
X_train = pd.get_dummies(X_train, columns=['Fare_bin'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['Fare_bin'], drop_first=True)

# %%
X_train.drop('Fare',axis=1,inplace=True)
X_test.drop('Fare',axis=1,inplace=True)

# %% [markdown]
# ### Cabin

# %% [markdown]
# In the training set, we only have 204 row have cabin information. In order to take them into account, we first create 'Cabin indicator' to indicates whether there is any information about cabin. And then, we add a new column'Deck' to get the first letter from the Cabin column that might to do with survival rate.

# %%
X_train['Cabin_ind'] = train_data['Cabin'].apply(lambda x: 0 if pd.isna(x) else 1)
X_test['Cabin_ind'] = test_data['Cabin'].apply(lambda x: 0 if pd.isna(x) else 1)

# %%
train_data['Deck'] = train_data['Cabin'].apply(lambda x: str(x)[0] if pd.notna(x) else 'M')  # 'M' for Missing
test_data['Deck'] = test_data['Cabin'].apply(lambda x: str(x)[0] if pd.notna(x) else 'M')

# %%
sns.barplot(x='Deck', y='Survived', data=train_data,palette='pastel')
plt.title('Survival Rate by Deck')
plt.show()

# %% [markdown]
# From above, we notice that in certain decks the survival rate is relatively higher than the others. Thus, we include this as a new column in our training feature.

# %%
X_train['Deck'] = train_data['Deck']
X_test['Deck'] = test_data['Deck']

# %%
X_train = pd.get_dummies(X_train, columns=['Deck'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['Deck'], drop_first=True)

# %%
X_train.info()
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pclass               891 non-null    int64
#  1   SibSp                891 non-null    int64
#  2   Parch                891 non-null    int64
#  3   Sex_male             891 non-null    uint8
#  4   Embarked_Q           891 non-null    uint8
#  5   Embarked_S           891 non-null    uint8
#  6   Title_Combined_Mr    891 non-null    uint8
#  7   Title_Combined_Mrs   891 non-null    uint8
#  8   Title_Combined_Rare  891 non-null    uint8
#  9   Age_Category_16-20   891 non-null    uint8
#  10  Age_Category_20-30   891 non-null    uint8
#  11  Age_Category_30-40   891 non-null    uint8
#  12  Age_Category_40-60   891 non-null    uint8
#  13  Age_Category_60-100  891 non-null    uint8
#  14  Fare_bin_10-50       891 non-null    uint8
#  15  Fare_bin_50-100      891 non-null    uint8
#  16  Fare_bin_100-200     891 non-null    uint8
#  17  Fare_bin_200+        891 non-null    uint8
#  18  Cabin_ind            891 non-null    int64
#  19  Deck_B               891 non-null    uint8
#  20  Deck_C               891 non-null    uint8
#  21  Deck_D               891 non-null    uint8
#  22  Deck_E               891 non-null    uint8
#  23  Deck_F               891 non-null    uint8
#  24  Deck_G               891 non-null    uint8
#  25  Deck_M               891 non-null    uint8
#  26  Deck_T               891 non-null    uint8
# dtypes: int64(4), uint8(23)
# memory usage: 48.0 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pclass               418 non-null    int64
#  1   SibSp                418 non-null    int64
#  2   Parch                418 non-null    int64
#  3   Sex_male             418 non-null    uint8
#  4   Embarked_Q           418 non-null    uint8
#  5   Embarked_S           418 non-null    uint8
#  6   Title_Combined_Mr    418 non-null    uint8
#  7   Title_Combined_Mrs   418 non-null    uint8
#  8   Title_Combined_Rare  418 non-null    uint8
#  9   Age_Category_16-20   418 non-null    uint8
#  10  Age_Category_20-30   418 non-null    uint8
#  11  Age_Category_30-40   418 non-null    uint8
#  12  Age_Category_40-60   418 non-null    uint8
#  13  Age_Category_60-100  418 non-null    uint8
#  14  Fare_bin_10-50       418 non-null    uint8
#  15  Fare_bin_50-100      418 non-null    uint8
#  16  Fare_bin_100-200     418 non-null    uint8
#  17  Fare_bin_200+        418 non-null    uint8
#  18  Cabin_ind            418 non-null    int64
#  19  Deck_B               418 non-null    uint8
#  20  Deck_C               418 non-null    uint8
#  21  Deck_D               418 non-null    uint8
#  22  Deck_E               418 non-null    uint8
#  23  Deck_F               418 non-null    uint8
#  24  Deck_G               418 non-null    uint8
#  25  Deck_M               418 non-null    uint8
# dtypes: int64(4), uint8(22)
# memory usage: 22.2 KB

# %% [markdown]
# ### Passenger Class

# %% [markdown]
# The survival rate also is to do with the class of the passenger. First class passenger has relatively higher survival rate in general, followed by 2nd passengers. Yet it is hard to decide whether we include this feature as dummy variable or continous value. We thus test these two method respectively.

# %%
sns.barplot(x='Pclass', y='Survived', data=train_data,palette='pastel')
plt.title('Survival Rate by Pclass')
plt.show()

# %%
X_train_Pclass_dm = pd.get_dummies(X_train, columns=['Pclass'], drop_first=True)
X_test_Pclass_dm = pd.get_dummies(X_test, columns=['Pclass'], drop_first=True)

# %%
print("P_class as continous variables:")

P_class_models, P_class_result = train_RF(X_train, y_train)

print("P_class as dummy variables:")

P_class_models, P_class_result = train_RF(X_train_Pclass_dm, y_train)
# Out:
# P_class as continous variables:
#     mean_test_score  std_test_score  \
# 15         0.831449        0.019490
# 46         0.831439        0.020079
# 70         0.831429        0.022484
# 59         0.830040        0.018708
# 71         0.830031        0.020796
#
#                                                params  rank_test_score
# 15  {'n_estimators': 100, 'min_samples_split': 10,...                1
# 46  {'n_estimators': 150, 'min_samples_split': 10,...                2
# 70  {'n_estimators': 150, 'min_samples_split': 10,...                3
# 59  {'n_estimators': 150, 'min_samples_split': 10,...                4
# 71  {'n_estimators': 100, 'min_samples_split': 10,...                5
# P_class as dummy variables:
#     mean_test_score  std_test_score  \
# 24         0.832847        0.014541
# 76         0.831429        0.015093
# 6          0.830050        0.010417
# 47         0.830040        0.012313
# 89         0.830031        0.011604
#
#                                                params  rank_test_score
# 24  {'n_estimators': 50, 'min_samples_split': 10, ...                1
# 76  {'n_estimators': 150, 'min_samples_split': 5, ...                2
# 6   {'n_estimators': 100, 'min_samples_split': 5, ...                3
# 47  {'n_estimators': 100, 'min_samples_split': 2, ...                4
# 89  {'n_estimators': 100, 'min_samples_split': 10,...                5

# %% [markdown]
# From the training result, we see that having Pclass has dummy variables might benefit our prediction better.

# %%
X_train=X_train_Pclass_dm
X_test=X_test_Pclass_dm

# %% [markdown]
# ### Family and Connection

# %% [markdown]
# We now move on to the feature of Parch and SibSp.

# %%
# Plot survival rate by SibSp
sns.barplot(x='SibSp', y='Survived', data=train_data,palette='pastel')
plt.title('Survival Rate by SibSp')
plt.show()

# %%
# Plot survival rate by Parch
sns.barplot(x='Parch', y='Survived', data=train_data,palette='pastel')
plt.title('Survival Rate by Parch')
plt.show()

# %% [markdown]
# It is hard to conclude whether having more relatives/friends on board will lead to higher survival rate. To Explore deeper in this part. Several other features have been created:
# **Family Size: where the feature of SibSp and Parch's values have been added together to identify the family size**
# ****

# %%
train_data['Family_size'] = train_data['SibSp'] + train_data['Parch'] 
test_data['Family_size'] = test_data['SibSp'] + test_data['Parch']

# %%
# Plot survival rate by Family Size
sns.barplot(x='Family_size', y='Survived', data=train_data,palette='pastel')
plt.title('Survival Rate by Family_size')
plt.show()

# %% [markdown]
# We can see that the survival rate goes up before the family size reaches 3. Yet, when family size is 4-5, the survival rate can be low. It gets higher for the family with 6 people, but the variance within this group can be high as well.We thus group some of this values together as below:

# %%
bins_Familysize = [0,1,3,5,10]
labels_Familysize = ['solo', 'Small','Medium','Large']

X_train['Familysize_Group'] = pd.cut(train_data['Family_size'], bins=bins_Familysize, labels=labels_Familysize , right=False)
X_test['Familysize_Group'] = pd.cut(test_data['Family_size'], bins=bins_Familysize, labels=labels_Familysize , right=False)

# %%
X_train = pd.get_dummies(X_train, columns=['Familysize_Group'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['Familysize_Group'], drop_first=True)

# %% [markdown]
# After adding the new feature, do we keep the Parch and SibSp features? The following models has been built to test which features do we include.

# %%
ParchSibSp_asDm_X_train=pd.get_dummies(X_train, columns=['Parch','SibSp'], drop_first=True)
ParchSibSp_asDm_X_test=pd.get_dummies(X_test, columns=['Parch','SibSp'], drop_first=True)

# %%
NoFamilysize_X_train=X_train.drop(columns=['Familysize_Group_Small','Familysize_Group_Medium','Familysize_Group_Large'])
NoFamilysize_X_test=X_test.drop(columns=['Familysize_Group_Small','Familysize_Group_Medium','Familysize_Group_Large'])

# %%
NoParchSibSp_X_train=X_train.drop(columns=['Parch','SibSp'])
NoParchSibSp_X_test=X_test.drop(columns=['Parch','SibSp'])

# %%
print("Keep Family_size and Parch/SibSp:")

Family_AllIncluded, result = train_RF(X_train, y_train)

print("Keep Family_size and Parch/SibSp as dummies:")

Family_AllIncludeddm, result = train_RF(ParchSibSp_asDm_X_train, y_train)

print("No family size:")

NoFamilysize_Included, result = train_RF(NoFamilysize_X_train, y_train)

print("No Parents/Siblings info:")
NoParchsib_Included,result = train_RF(NoParchSibSp_X_train, y_train)
# Out:
# Keep Family_size and Parch/SibSp:

# %% [markdown]
# After we read the result from validation result, we decide to remove the family size variable for now. Yet, it might get back later since the test result might differ with the cross-validation set.

# %%
X_train=ParchSibSp_asDm_X_train
X_test=ParchSibSp_asDm_X_test

# %% [markdown]
# ### Is Mother or not

# %%
def is_mother(row):
    return row['Title'] == 'Mrs' and row['Parch'] > 0

# Apply the function to create the 'Is_Mother' column
train_data['Is_Mother'] = train_data.apply(is_mother, axis=1).astype(int)
test_data['Is_Mother'] = test_data.apply(is_mother, axis=1).astype(int)

# %%
X_train = pd.concat([X_train, train_data[['Is_Mother']]], axis=1)
X_test = pd.concat([X_test, test_data[['Is_Mother']]], axis=1)

# %% [markdown]
# ### Ticket Number

# %%
train_data['Ticket'].describe()

# %% [markdown]
# From the analysis above, we see that there are people holding same ticket in the dataset. Maybe they tend to share the same survival result and thus we build a new variable called 'connected survival'.

# %%
combined_data = pd.concat([train_data, test_data], axis=0, ignore_index=True)
combined_data['Is_Duplicate_Ticket'] = combined_data.duplicated(subset=['Ticket'], keep=False)
combined_data['Connected_Survival'] = 0.5 #We give a 0.5 survival rate to all passengers first.

for ticket, ticket_gp in combined_data.groupby('Ticket'):
    if len(ticket_gp) > 1:  # Only consider tickets with more than one passenger
        smean = ticket_gp['Survived'].mean()
        for ind, row in ticket_gp.iterrows():  # if the majority in the group survived, we assign connected survival= 1 to all the passengers share the ticket. 
            passID = row['PassengerId']
            if smean >= 0.5:
                combined_data.loc[combined_data['PassengerId'] == passID, 'Connected_Survival'] = 1
            elif smean < 0.5:
                combined_data.loc[combined_data['PassengerId'] == passID, 'Connected_Survival'] = 0

print('People with duplicate tickets: %.0f' % combined_data['Is_Duplicate_Ticket'].sum())
print("People with connected survival information: %.0f" % 
      (combined_data[combined_data['Connected_Survival'] != 0.5].shape[0]))

print(combined_data.groupby('Connected_Survival')['Survived'].mean().round(3))

print(combined_data[['Ticket', 'Connected_Survival']].head())
# Out:
# People with duplicate tickets: 596
# People with connected survival information: 562
# Connected_Survival
# 0.0    0.013
# 0.5    0.270
# 1.0    0.808
# Name: Survived, dtype: float64
#              Ticket  Connected_Survival
# 0         A/5 21171                 0.5
# 1          PC 17599                 1.0
# 2  STON/O2. 3101282                 0.5
# 3            113803                 1.0
# 4            373450                 0.5

# %%
train_data['Connected_Survival'] = combined_data['Connected_Survival'].iloc[:len(train_data)]
test_data['Connected_Survival'] = combined_data['Connected_Survival'].iloc[len(train_data):].reset_index(drop=True)

# %%
X_with_cs= pd.concat([X_train, train_data[['Connected_Survival']]], axis=1)

# %%
print("With Connected Survival:")

X_cs_models, C_result = train_RF(X_with_cs, y_train)

print("Without Connected Survival:")

X_wcs_models, C_result = train_RF(X_train, y_train)
# Out:
# With Connected Survival:
#     mean_test_score  std_test_score  \
# 2          0.873574        0.015586
# 8          0.873574        0.015586
# 95         0.872166        0.017073
# 39         0.872166        0.020745
# 48         0.870757        0.016014
#
#                                                params  rank_test_score
# 2   {'n_estimators': 100, 'min_samples_split': 5, ...                1
# 8   {'n_estimators': 100, 'min_samples_split': 2, ...                1
# 95  {'n_estimators': 100, 'min_samples_split': 5, ...                3
# 39  {'n_estimators': 50, 'min_samples_split': 10, ...                4
# 48  {'n_estimators': 100, 'min_samples_split': 2, ...                5
# Without Connected Survival:
#     mean_test_score  std_test_score  \
# 78         0.831439        0.012064
# 24         0.830050        0.005426
# 46         0.830031        0.020796
# 12         0.828642        0.018229
# 76         0.828642        0.015904
#
#                                                params  rank_test_score
# 78  {'n_estimators': 150, 'min_samples_split': 5, ...                1
# 24  {'n_estimators': 50, 'min_samples_split': 10, ...                2
# 46  {'n_estimators': 150, 'min_samples_split': 10,...                3
# 12  {'n_estimators': 150, 'min_samples_split': 2, ...                4
# 76  {'n_estimators': 150, 'min_samples_split': 5, ...                4

# %% [markdown]
# This is a BIG JUMP! So we include this new feature into our model:

# %%
X_train['Connected_Survival'] = combined_data['Connected_Survival'].iloc[:len(train_data)]
X_test['Connected_Survival'] = combined_data['Connected_Survival'].iloc[len(train_data):].reset_index(drop=True)

# %% [markdown]
# ### Finalising Training Set and Test Set

# %% [markdown]
# Now we need to check whether training set and test set has the same numbers of columns:

# %%
train_columns = set(X_train.columns)
test_columns = set(X_test.columns)

# %%
missing_cols_test = train_columns - test_columns

# %%
missing_cols_test
# Out:
# set()

# %%
for col in missing_cols_test:
    X_test[col] = 0

# %%
X_test = X_test[X_train.columns]

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sex_male                 418 non-null    float64
#  1   Embarked_Q               418 non-null    float64
#  2   Embarked_S               418 non-null    float64
#  3   Title_Combined_Mr        418 non-null    float64
#  4   Title_Combined_Mrs       418 non-null    float64
#  5   Title_Combined_Rare      418 non-null    float64
#  6   Age_Category_16-20       418 non-null    float64
#  7   Age_Category_20-30       418 non-null    float64
#  8   Age_Category_30-40       418 non-null    float64
#  9   Age_Category_40-60       418 non-null    float64
#  10  Age_Category_60-100      418 non-null    float64
#  11  Fare_bin_10-50           418 non-null    float64
#  12  Fare_bin_50-100          418 non-null    float64
#  13  Fare_bin_100-200         418 non-null    float64
#  14  Fare_bin_200+            418 non-null    float64
#  15  Cabin_ind                418 non-null    float64
#  16  Deck_B                   418 non-null    float64
#  17  Deck_C                   418 non-null    float64
#  18  Deck_D                   418 non-null    float64
#  19  Deck_E                   418 non-null    float64
#  20  Deck_F                   418 non-null    float64
#  21  Deck_G                   418 non-null    float64
#  22  Deck_M                   418 non-null    float64
#  23  Deck_T                   891 non-null    int64
#  24  Pclass_2                 418 non-null    float64
#  25  Pclass_3                 418 non-null    float64
#  26  Familysize_Group_Small   418 non-null    float64
#  27  Familysize_Group_Medium  418 non-null    float64
#  28  Familysize_Group_Large   418 non-null    float64
#  29  Parch_1                  418 non-null    float64
#  30  Parch_2                  418 non-null    float64
#  31  Parch_3                  418 non-null    float64
#  32  Parch_4                  418 non-null    float64
#  33  Parch_5                  418 non-null    float64
#  34  Parch_6                  418 non-null    float64
#  35  SibSp_1                  418 non-null    float64
#  36  SibSp_2                  418 non-null    float64
#  37  SibSp_3                  418 non-null    float64
#  38  SibSp_4                  418 non-null    float64
#  39  SibSp_5                  418 non-null    float64
#  40  SibSp_8                  418 non-null    float64
#  41  Is_Mother                891 non-null    int32
#  42  Connected_Survival       418 non-null    float64
# dtypes: float64(41), int32(1), int64(1)
# memory usage: 296.0 KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sex_male                 891 non-null    uint8
#  1   Embarked_Q               891 non-null    uint8
#  2   Embarked_S               891 non-null    uint8
#  3   Title_Combined_Mr        891 non-null    uint8
#  4   Title_Combined_Mrs       891 non-null    uint8
#  5   Title_Combined_Rare      891 non-null    uint8
#  6   Age_Category_16-20       891 non-null    uint8
#  7   Age_Category_20-30       891 non-null    uint8
#  8   Age_Category_30-40       891 non-null    uint8
#  9   Age_Category_40-60       891 non-null    uint8
#  10  Age_Category_60-100      891 non-null    uint8
#  11  Fare_bin_10-50           891 non-null    uint8
#  12  Fare_bin_50-100          891 non-null    uint8
#  13  Fare_bin_100-200         891 non-null    uint8
#  14  Fare_bin_200+            891 non-null    uint8
#  15  Cabin_ind                891 non-null    int64
#  16  Deck_B                   891 non-null    uint8
#  17  Deck_C                   891 non-null    uint8
#  18  Deck_D                   891 non-null    uint8
#  19  Deck_E                   891 non-null    uint8
#  20  Deck_F                   891 non-null    uint8
#  21  Deck_G                   891 non-null    uint8
#  22  Deck_M                   891 non-null    uint8
#  23  Deck_T                   891 non-null    uint8
#  24  Pclass_2                 891 non-null    uint8
#  25  Pclass_3                 891 non-null    uint8
#  26  Familysize_Group_Small   891 non-null    uint8
#  27  Familysize_Group_Medium  891 non-null    uint8
#  28  Familysize_Group_Large   891 non-null    uint8
#  29  Parch_1                  891 non-null    uint8
#  30  Parch_2                  891 non-null    uint8
#  31  Parch_3                  891 non-null    uint8
#  32  Parch_4                  891 non-null    uint8
#  33  Parch_5                  891 non-null    uint8
#  34  Parch_6                  891 non-null    uint8
#  35  SibSp_1                  891 non-null    uint8
#  36  SibSp_2                  891 non-null    uint8
#  37  SibSp_3                  891 non-null    uint8
#  38  SibSp_4                  891 non-null    uint8
#  39  SibSp_5                  891 non-null    uint8
#  40  SibSp_8                  891 non-null    uint8
#  41  Is_Mother                891 non-null    int32
#  42  Connected_Survival       891 non-null    float64
# dtypes: float64(1), int32(1), int64(1), uint8(40)
# memory usage: 52.3 KB

# %% [markdown]
# Now, both of them have same numbers of columns and is ready for the training stage.

# %% [markdown]
# ## Model Training

# %%
def train_RF(X_train,y_train):

    X_train_split, X_val, y_train_split, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
    
    param_grid = {
        'n_estimators': [50, 100, 150],
        'max_depth': [None, 5, 10, 15],
        'max_features': ['sqrt', 'log2'],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'bootstrap': [True, False]
    }
    
    randomized_search = RandomizedSearchCV(
        estimator=RandomForestClassifier(random_state=44),
        param_distributions=param_grid,
        n_iter=100,  # Number of parameter settings sampled
        n_jobs=-1,
        scoring='accuracy',
        random_state=44,
        cv=5
        )

    randomized_search.fit(X_train_split, y_train_split)
    results = randomized_search.cv_results_

    results_df = pd.DataFrame({
        'mean_test_score': results['mean_test_score'],
        'std_test_score': results['std_test_score'],
        'params': results['params'],
        'rank_test_score': results['rank_test_score']
        })
    sorted_results_df = results_df.sort_values(by='rank_test_score')
    top_5_results = sorted_results_df.head(5)

    # Initialize an empty list to store the top models
    top_models = []
    result=[]
    # Loop through the top 5 results and build models using those parameters
    for idx, row in top_5_results.iterrows():
        params = row['params']
        model = RandomForestClassifier(**params)
        model.fit(X_train_split, y_train_split) 
        top_models.append(model)
        scores = cross_val_score(model, X_train_split, y_train_split, cv=5, scoring='accuracy')  # 5-fold cross-validation
        mean_accuracy = np.mean(scores)
        std_accuracy = np.std(scores)
        result.append((mean_accuracy,std_accuracy))
    print(sorted_results_df.head(5))
    return(top_models,result)

# %%
param_grid = {
    'n_estimators': [25, 50, 75, 100, 150,125],           # Number of trees in the forest
    'max_depth': [5, 6, 7, 8, 9, 10],                # Maximum depth of the tree
    'max_features': ['sqrt', 'log2'],        # Number of features to consider for the best split
    'min_samples_split': [2, 5, 10],                 # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4,8],                   # Minimum number of samples required to be at a leaf node
    'bootstrap': [True, False]                       # Whether bootstrap samples are used when building trees
}

# %%
X_train_split, X_val, y_train_split, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
randomized_search = RandomizedSearchCV(
    estimator=RandomForestClassifier(random_state=44),
    param_distributions=param_grid,
    n_iter=1000,  # Number of parameter settings sampled
    n_jobs=-1,
    scoring='accuracy',
    random_state=44
)

randomized_search.fit(X_train_split, y_train_split)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=44),
#                    n_iter=1000, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [5, 6, 7, 8, 9, 10],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 8],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [25, 50, 75, 100, 150,
#                                                          125]},
#                    random_state=44, scoring='accuracy')

# %%
results = randomized_search.cv_results_

results_df = pd.DataFrame({
    'mean_test_score': results['mean_test_score'],
    'std_test_score': results['std_test_score'],
    'params': results['params'],
    'rank_test_score': results['rank_test_score']
})

print(results_df.sort_values(by='rank_test_score'))
# Out:
#      mean_test_score  std_test_score  \
# 751         0.873574        0.015586
# 750         0.873574        0.015586
# 521         0.872176        0.018673
# 800         0.872176        0.018673
# 396         0.872176        0.015154
# ..               ...             ...
# 958         0.846863        0.016063
# 899         0.846863        0.016063
# 421         0.846863        0.014109
# 747         0.845484        0.012794
# 63          0.845455        0.015228
#
#                                                 params  rank_test_score
# 751  {'n_estimators': 100, 'min_samples_split': 5, ...                1
# 750  {'n_estimators': 125, 'min_samples_split': 5, ...                1
# 521  {'n_estimators': 125, 'min_samples_split': 2, ...                3
# 800  {'n_estimators': 125, 'min_samples_split': 5, ...                3
# 396  {'n_estimators': 150, 'min_samples_split': 10,...                3
# ..                                                 ...              ...
# 958  {'n_estimators': 25, 'min_samples_split': 2, '...              996
# 899  {'n_estimators': 25, 'min_samples_split': 5, '...              996
# 421  {'n_estimators': 50, 'min_samples_split': 10, ...              998
# 747  {'n_estimators': 25, 'min_samples_split': 2, '...              999
# 63   {'n_estimators': 50, 'min_samples_split': 10, ...             1000
#
# [1000 rows x 4 columns]

# %%
top_10_results = results_df.sort_values(by='rank_test_score').head(10)

# Initialize an empty list to store the top models
top_models = []

# Loop through the top 5 results and build models using those parameters
for idx, row in top_10_results.iterrows():
    params = row['params']
    model = RandomForestClassifier(**params)
    top_models.append(model)
    
print(top_models)
# Out:
# [RandomForestClassifier(max_depth=6, max_features='log2', min_samples_leaf=2,
#                        min_samples_split=5), RandomForestClassifier(max_depth=10, max_features='log2', min_samples_leaf=4,
#                        min_samples_split=5, n_estimators=125), RandomForestClassifier(max_depth=8, max_features='log2', min_samples_leaf=4,
#                        n_estimators=125), RandomForestClassifier(max_depth=8, max_features='log2', min_samples_leaf=4,
#                        min_samples_split=5, n_estimators=125), RandomForestClassifier(max_depth=8, max_features='log2', min_samples_leaf=4,
#                        min_samples_split=10, n_estimators=150), RandomForestClassifier(max_depth=8, max_features='log2', min_samples_leaf=4,
#                        min_samples_split=5), RandomForestClassifier(max_depth=7, max_features='log2', min_samples_leaf=4), RandomForestClassifier(max_depth=8, max_features='log2', min_samples_leaf=4,
#                        min_samples_split=10, n_estimators=125), RandomForestClassifier(max_depth=10, max_features='log2', min_samples_leaf=4,
#                        min_samples_split=5), RandomForestClassifier(max_depth=10, max_features='log2', min_samples_leaf=4,
#                        min_samples_split=10, n_estimators=50)]

# %%
for model in top_models:
    model.fit(X_train_split, y_train_split)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Get feature names
feature_names = X_train_split.columns

# Plotting feature importances for each model
for i, model in enumerate(top_models):
    importances = model.feature_importances_
    importance_df = pd.DataFrame({
        'feature': feature_names,
        'importance': importances
    })
    importance_df = importance_df.sort_values(by='importance', ascending=False)
    
    # Plot
    plt.figure(figsize=(10, 6))
    sns.barplot(x='importance', y='feature', data=importance_df)
    plt.title(f'Feature Importances for Model {i+1}')
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.show()

# %%
from sklearn.ensemble import VotingClassifier

model_list = [(f'model_{i+1}', model) for i, model in enumerate(top_models)]
voting_clf = VotingClassifier(estimators=model_list, voting='soft')  
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('model_1',
#                               RandomForestClassifier(max_depth=6,
#                                                      max_features='log2',
#                                                      min_samples_leaf=2,
#                                                      min_samples_split=5)),
#                              ('model_2',
#                               RandomForestClassifier(max_depth=10,
#                                                      max_features='log2',
#                                                      min_samples_leaf=4,
#                                                      min_samples_split=5,
#                                                      n_estimators=125)),
#                              ('model_3',
#                               RandomForestClassifier(max_depth=8,
#                                                      max_features='log2',
#                                                      min_samples_leaf=4,
#                                                      n_es...
#                               RandomForestClassifier(max_depth=8,
#                                                      max_features='log2',
#                                                      min_samples_leaf=4,
#                                                      min_samples_split=10,
#                                                      n_estimators=125)),
#                              ('model_9',
#                               RandomForestClassifier(max_depth=10,
#                                                      max_features='log2',
#                                                      min_samples_leaf=4,
#                                                      min_samples_split=5)),
#                              ('model_10',
#                               RandomForestClassifier(max_depth=10,
#                                                      max_features='log2',
#                                                      min_samples_leaf=4,
#                                                      min_samples_split=10,
#                                                      n_estimators=50))],
#                  voting='soft')

# %%
predictions = voting_clf.predict(X_test)

results = pd.DataFrame({
    'PassengerId': test_data['PassengerId'],
    'Survived': predictions
})

results.to_csv('prediction_voting03.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[368], line 1
# ----> 1 predictions = voting_clf.predict(X_test)
#       3 results = pd.DataFrame({
#       4     'PassengerId': test_data['PassengerId'],
#       5     'Survived': predictions
#       6 })
#       8 results.to_csv('prediction_voting03.csv', index=False)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_voting.py:363, in VotingClassifier.predict(self, X)
#     361 check_is_fitted(self)
#     362 if self.voting == "soft":
# --> 363     maj = np.argmax(self.predict_proba(X), axis=1)
#     365 else:  # 'hard' voting
#     366     predictions = self._predict(X)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_voting.py:404, in VotingClassifier.predict_proba(self, X)
#     390 """Compute probabilities of possible outcomes for samples in X.
#     391
#     392 Parameters
#    (...)
#     400     Weighted average probability for each class per sample.
#     401 """
#     402 check_is_fitted(self)
#     403 avg = np.average(
# --> 404     self._collect_probas(X), axis=0, weights=self._weights_not_none
#     405 )
#     406 return avg
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_voting.py:379, in VotingClassifier._collect_probas(self, X)
#     377 def _collect_probas(self, X):
#     378     """Collect results from clf.predict calls."""
# --> 379     return np.asarray([clf.predict_proba(X) for clf in self.estimators_])
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_voting.py:379, in <listcomp>(.0)
#     377 def _collect_probas(self, X):
#     378     """Collect results from clf.predict calls."""
# --> 379     return np.asarray([clf.predict_proba(X) for clf in self.estimators_])
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:862, in ForestClassifier.predict_proba(self, X)
#     860 check_is_fitted(self)
#     861 # Check data
# --> 862 X = self._validate_X_predict(X)
#     864 # Assign chunk of trees to jobs
#     865 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:602, in BaseForest._validate_X_predict(self, X)
#     599 """
#     600 Validate X whenever one tries to predict, apply, predict_proba."""
#     601 check_is_fitted(self)
# --> 602 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     603 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     604     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# RandomForestClassifier does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
