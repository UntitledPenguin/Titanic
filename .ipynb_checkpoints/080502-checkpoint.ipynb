# %% [markdown]
# ## Data exploration and transformation

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
print("Training Data Overview:")
print(train_data.info())
# Out:
# Training Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
print("Test Data Overview:")
print(test_data.info())
# Out:
# Test Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB
# None

# %%
train_data['Title'] = train_data['Name'].apply(lambda x: x.split(',')[1].split('.')[0].strip())
test_data['Title'] = test_data['Name'].apply(lambda x: x.split(',')[1].split('.')[0].strip())

# %%
print(train_data['Title'].unique())
print(test_data['Title'].unique())
# Out:
# ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Mme' 'Ms' 'Major' 'Lady'
#  'Sir' 'Mlle' 'Col' 'Capt' 'the Countess' 'Jonkheer']
# ['Mr' 'Mrs' 'Miss' 'Master' 'Ms' 'Col' 'Rev' 'Dr' 'Dona']

# %%
plt.figure(figsize=(10, 6))
train_data['Title'].value_counts().sort_values().plot(kind='barh')
plt.title('Distribution of Titles')
plt.xlabel('Count')
plt.ylabel('Title')
plt.show()

# %%
title_survival_rate = train_data.groupby('Title')['Survived'].mean()

print(title_survival_rate)

plt.figure(figsize=(12, 6))
title_survival_rate.sort_values().plot(kind='barh', color='skyblue')
plt.title('Survival Rate by Title')
plt.xlabel('Survival Rate')
plt.ylabel('Title')
plt.show()
# Out:
# Title
# Capt            0.000000
# Col             0.500000
# Don             0.000000
# Dr              0.428571
# Jonkheer        0.000000
# Lady            1.000000
# Major           0.500000
# Master          0.575000
# Miss            0.697802
# Mlle            1.000000
# Mme             1.000000
# Mr              0.156673
# Mrs             0.792000
# Ms              1.000000
# Rev             0.000000
# Sir             1.000000
# the Countess    1.000000
# Name: Survived, dtype: float64

# %%
def get_titles(title):
    if title in ['Mme', 'Ms', 'Lady', 'Dona']:
        return 'Mrs'
    elif title in ['Mlle', 'the Countess']:
        return 'Miss'
    elif title in ['Capt', 'Col', 'Major', 'Dr', 'Rev', 'Jonkheer', 'Don', 'Sir','Master']:
        return 'Rare'
    else:
        return title

# %%
train_data['Title'] = train_data['Title'].apply(get_titles)
test_data['Title'] = test_data['Title'].apply(get_titles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 train_data['Title'] = train_data['Title'].apply(get_titles)
#       2 test_data['Title'] = test_data['Title'].apply(get_titles)
#
# NameError: name 'get_titles' is not defined

# %%
train_data = pd.get_dummies(train_data, columns=['Title'], prefix='Title')
test_data = pd.get_dummies(test_data, columns=['Title'], prefix='Title')

# %%
train_data.drop('Name', axis=1, inplace=True)
test_data.drop('Name', axis=1, inplace=True)

# %%
train_data['Age'] = pd.to_numeric(train_data['Age'], errors='coerce')
test_data['Age'] = pd.to_numeric(test_data['Age'], errors='coerce')

# %%
test_data['Age'].plot(kind='hist', bins=100, edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_distribution(col_x,key):
 sns.kdeplot(data=train_data[train_data[key] == 1], x=col_x, label='Survived', color='green', fill=True)
 sns.kdeplot(data=train_data[train_data[key] == 0], x=col_x, label='Not Survived', color='red', fill=True)

 plt.xlabel(col_x)
 plt.ylabel('Density')
 plt.title(f'Density Plot of {col_x} by {key}')
 plt.legend()

 plt.show()

# %%
plot_distribution('Age','Survived')

# %%
train_data['Age'].fillna(train_data['Age'].mean(), inplace=True)
test_data['Age'].fillna(test_data['Age'].mean(), inplace=True)

# %%
bins_age = [0, 5, 10,15,20,25,30,35,40,50,60,70,100] 
labels_age = ['0-5','5-10','10-15','15-20','20-25', '25-30','30-35','35-40', '40-50','50-60','60-70','70-100']

# %%
train_data['Age_Category'] = pd.cut(train_data['Age'], bins=bins_age, labels=labels_age, right=True)
test_data['Age_Category'] = pd.cut(test_data['Age'], bins=bins_age, labels=labels_age, right=True)

# %%
age_survival_rate = train_data.groupby('Age_Category')['Survived'].mean()

print(age_survival_rate)
# Out:
# Age_Category
# 0-5       0.704545
# 5-10      0.350000
# 10-15     0.578947
# 15-20     0.343750
# 20-25     0.344262
# 25-30     0.329825
# 30-35     0.465909
# 35-40     0.417910
# 40-50     0.383721
# 50-60     0.404762
# 60-70     0.235294
# 70-100    0.200000
# Name: Survived, dtype: float64

# %%
train_data = pd.get_dummies(train_data, columns=['Age_Category'], drop_first=True)
test_data = pd.get_dummies(test_data, columns=['Age_Category'], drop_first=True)

# %%
test_data['Fare'].fillna(test_data['Fare'].mean(), inplace=True)

# %%
test_data['Fare'].dtype
# Out:
# dtype('float64')

# %%
test_data['Fare'].plot(kind='hist', bins=100, edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of Values')
plt.show()

# %%
bins_fare = [0, 5,10,15, 20, 25, 30, 40, 50, 65,80, 100, 150,200,250,300, 600]
labels_fare = ['0-5', '5-10','10-15','15-20','20-25','25-30', '30-40', '40-50', '50-65','65-80','80-100','100-150', '150-200','200-250','250-300','300+']

train_data['Fare_bin'] = pd.cut(train_data['Fare'], bins=bins_fare, labels=labels_fare, right=False)
test_data['Fare_bin'] = pd.cut(train_data['Fare'], bins=bins_fare, labels=labels_fare, right=False)

# %%
fare_survival_rate = train_data.groupby('Fare_bin')['Survived'].mean()

print(fare_survival_rate)

plt.figure(figsize=(12, 6))
fare_survival_rate.sort_values().plot(kind='barh', color='skyblue')
plt.title('Survival Rate by Fare')
plt.xlabel('Survival Rate')
plt.ylabel('Fare')
plt.show()
# Out:
# Fare_bin
# 0-5        0.062500
# 5-10       0.206250
# 10-15      0.388430
# 15-20      0.500000
# 20-25      0.404762
# 25-30      0.436170
# 30-40      0.437500
# 40-50      0.266667
# 50-65      0.651163
# 65-80      0.523810
# 80-100     0.869565
# 100-150    0.791667
# 150-200    0.666667
# 200-250    0.636364
# 250-300    0.666667
# 300+       1.000000
# Name: Survived, dtype: float64

# %%
plot_distribution('Fare','Survived')

# %%
train_data = pd.get_dummies(train_data, columns=['Fare_bin'], drop_first=True)
test_data = pd.get_dummies(test_data, columns=['Fare_bin'], drop_first=True)

# %%
print(test_data.info())
print(train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 45 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PassengerId          418 non-null    int64
#  1   Pclass               418 non-null    int64
#  2   Sex                  418 non-null    object
#  3   Age                  418 non-null    float64
#  4   SibSp                418 non-null    int64
#  5   Parch                418 non-null    int64
#  6   Ticket               418 non-null    object
#  7   Fare                 418 non-null    float64
#  8   Cabin                91 non-null     object
#  9   Embarked             418 non-null    object
#  10  Title_Col            418 non-null    uint8
#  11  Title_Dona           418 non-null    uint8
#  12  Title_Dr             418 non-null    uint8
#  13  Title_Master         418 non-null    uint8
#  14  Title_Miss           418 non-null    uint8
#  15  Title_Mr             418 non-null    uint8
#  16  Title_Mrs            418 non-null    uint8
#  17  Title_Ms             418 non-null    uint8
#  18  Title_Rev            418 non-null    uint8
#  19  Age_Category_5-10    418 non-null    uint8
#  20  Age_Category_10-15   418 non-null    uint8
#  21  Age_Category_15-20   418 non-null    uint8
#  22  Age_Category_20-25   418 non-null    uint8
#  23  Age_Category_25-30   418 non-null    uint8
#  24  Age_Category_30-35   418 non-null    uint8
#  25  Age_Category_35-40   418 non-null    uint8
#  26  Age_Category_40-50   418 non-null    uint8
#  27  Age_Category_50-60   418 non-null    uint8
#  28  Age_Category_60-70   418 non-null    uint8
#  29  Age_Category_70-100  418 non-null    uint8
#  30  Fare_bin_5-10        418 non-null    uint8
#  31  Fare_bin_10-15       418 non-null    uint8
#  32  Fare_bin_15-20       418 non-null    uint8
#  33  Fare_bin_20-25       418 non-null    uint8
#  34  Fare_bin_25-30       418 non-null    uint8
#  35  Fare_bin_30-40       418 non-null    uint8
#  36  Fare_bin_40-50       418 non-null    uint8
#  37  Fare_bin_50-65       418 non-null    uint8
#  38  Fare_bin_65-80       418 non-null    uint8
#  39  Fare_bin_80-100      418 non-null    uint8
#  40  Fare_bin_100-150     418 non-null    uint8
#  41  Fare_bin_150-200     418 non-null    uint8
#  42  Fare_bin_200-250     418 non-null    uint8
#  43  Fare_bin_250-300     418 non-null    uint8
#  44  Fare_bin_300+        418 non-null    uint8
# dtypes: float64(2), int64(4), object(4), uint8(35)
# memory usage: 47.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PassengerId          891 non-null    int64
#  1   Survived             891 non-null    int64
#  2   Pclass               891 non-null    int64
#  3   Sex                  891 non-null    object
#  4   Age                  891 non-null    float64
#  5   SibSp                891 non-null    int64
#  6   Parch                891 non-null    int64
#  7   Ticket               891 non-null    object
#  8   Fare                 891 non-null    float64
#  9   Cabin                204 non-null    object
#  10  Embarked             889 non-null    object
#  11  Title_Capt           891 non-null    uint8
#  12  Title_Col            891 non-null    uint8
#  13  Title_Don            891 non-null    uint8
#  14  Title_Dr             891 non-null    uint8
#  15  Title_Jonkheer       891 non-null    uint8
#  16  Title_Lady           891 non-null    uint8
#  17  Title_Major          891 non-null    uint8
#  18  Title_Master         891 non-null    uint8
#  19  Title_Miss           891 non-null    uint8
#  20  Title_Mlle           891 non-null    uint8
#  21  Title_Mme            891 non-null    uint8
#  22  Title_Mr             891 non-null    uint8
#  23  Title_Mrs            891 non-null    uint8
#  24  Title_Ms             891 non-null    uint8
#  25  Title_Rev            891 non-null    uint8
#  26  Title_Sir            891 non-null    uint8
#  27  Title_the Countess   891 non-null    uint8
#  28  Age_Category_5-10    891 non-null    uint8
#  29  Age_Category_10-15   891 non-null    uint8
#  30  Age_Category_15-20   891 non-null    uint8
#  31  Age_Category_20-25   891 non-null    uint8
#  32  Age_Category_25-30   891 non-null    uint8
#  33  Age_Category_30-35   891 non-null    uint8
#  34  Age_Category_35-40   891 non-null    uint8
#  35  Age_Category_40-50   891 non-null    uint8
#  36  Age_Category_50-60   891 non-null    uint8
#  37  Age_Category_60-70   891 non-null    uint8
#  38  Age_Category_70-100  891 non-null    uint8
#  39  Fare_bin_5-10        891 non-null    uint8
#  40  Fare_bin_10-15       891 non-null    uint8
#  41  Fare_bin_15-20       891 non-null    uint8
#  42  Fare_bin_20-25       891 non-null    uint8
#  43  Fare_bin_25-30       891 non-null    uint8
#  44  Fare_bin_30-40       891 non-null    uint8
#  45  Fare_bin_40-50       891 non-null    uint8
#  46  Fare_bin_50-65       891 non-null    uint8
#  47  Fare_bin_65-80       891 non-null    uint8
#  48  Fare_bin_80-100      891 non-null    uint8
#  49  Fare_bin_100-150     891 non-null    uint8
#  50  Fare_bin_150-200     891 non-null    uint8
#  51  Fare_bin_200-250     891 non-null    uint8
#  52  Fare_bin_250-300     891 non-null    uint8
#  53  Fare_bin_300+        891 non-null    uint8
# dtypes: float64(2), int64(5), object(4), uint8(43)
# memory usage: 114.1+ KB
# None

# %%
train_data['Cabin_ind'] = train_data['Cabin'].apply(lambda x: 0 if pd.isna(x) else 1)
test_data['Cabin_ind'] = test_data['Cabin'].apply(lambda x: 0 if pd.isna(x) else 1)

# %%
train_data['Deck'] = train_data['Cabin'].apply(lambda x: str(x)[0] if pd.notna(x) else 'M')  # 'M' for Missing
test_data['Deck'] = test_data['Cabin'].apply(lambda x: str(x)[0] if pd.notna(x) else 'M')

# %%
train_data.drop('Cabin', axis=1, inplace=True)
test_data.drop('Cabin', axis=1, inplace=True)
print(test_data.info())
print(train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 46 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PassengerId          418 non-null    int64
#  1   Pclass               418 non-null    int64
#  2   Sex                  418 non-null    object
#  3   Age                  418 non-null    float64
#  4   SibSp                418 non-null    int64
#  5   Parch                418 non-null    int64
#  6   Ticket               418 non-null    object
#  7   Fare                 418 non-null    float64
#  8   Embarked             418 non-null    object
#  9   Title_Col            418 non-null    uint8
#  10  Title_Dona           418 non-null    uint8
#  11  Title_Dr             418 non-null    uint8
#  12  Title_Master         418 non-null    uint8
#  13  Title_Miss           418 non-null    uint8
#  14  Title_Mr             418 non-null    uint8
#  15  Title_Mrs            418 non-null    uint8
#  16  Title_Ms             418 non-null    uint8
#  17  Title_Rev            418 non-null    uint8
#  18  Age_Category_5-10    418 non-null    uint8
#  19  Age_Category_10-15   418 non-null    uint8
#  20  Age_Category_15-20   418 non-null    uint8
#  21  Age_Category_20-25   418 non-null    uint8
#  22  Age_Category_25-30   418 non-null    uint8
#  23  Age_Category_30-35   418 non-null    uint8
#  24  Age_Category_35-40   418 non-null    uint8
#  25  Age_Category_40-50   418 non-null    uint8
#  26  Age_Category_50-60   418 non-null    uint8
#  27  Age_Category_60-70   418 non-null    uint8
#  28  Age_Category_70-100  418 non-null    uint8
#  29  Fare_bin_5-10        418 non-null    uint8
#  30  Fare_bin_10-15       418 non-null    uint8
#  31  Fare_bin_15-20       418 non-null    uint8
#  32  Fare_bin_20-25       418 non-null    uint8
#  33  Fare_bin_25-30       418 non-null    uint8
#  34  Fare_bin_30-40       418 non-null    uint8
#  35  Fare_bin_40-50       418 non-null    uint8
#  36  Fare_bin_50-65       418 non-null    uint8
#  37  Fare_bin_65-80       418 non-null    uint8
#  38  Fare_bin_80-100      418 non-null    uint8
#  39  Fare_bin_100-150     418 non-null    uint8
#  40  Fare_bin_150-200     418 non-null    uint8
#  41  Fare_bin_200-250     418 non-null    uint8
#  42  Fare_bin_250-300     418 non-null    uint8
#  43  Fare_bin_300+        418 non-null    uint8
#  44  Cabin_ind            418 non-null    int64
#  45  Deck                 418 non-null    object
# dtypes: float64(2), int64(5), object(4), uint8(35)
# memory usage: 50.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 55 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PassengerId          891 non-null    int64
#  1   Survived             891 non-null    int64
#  2   Pclass               891 non-null    int64
#  3   Sex                  891 non-null    object
#  4   Age                  891 non-null    float64
#  5   SibSp                891 non-null    int64
#  6   Parch                891 non-null    int64
#  7   Ticket               891 non-null    object
#  8   Fare                 891 non-null    float64
#  9   Embarked             889 non-null    object
#  10  Title_Capt           891 non-null    uint8
#  11  Title_Col            891 non-null    uint8
#  12  Title_Don            891 non-null    uint8
#  13  Title_Dr             891 non-null    uint8
#  14  Title_Jonkheer       891 non-null    uint8
#  15  Title_Lady           891 non-null    uint8
#  16  Title_Major          891 non-null    uint8
#  17  Title_Master         891 non-null    uint8
#  18  Title_Miss           891 non-null    uint8
#  19  Title_Mlle           891 non-null    uint8
#  20  Title_Mme            891 non-null    uint8
#  21  Title_Mr             891 non-null    uint8
#  22  Title_Mrs            891 non-null    uint8
#  23  Title_Ms             891 non-null    uint8
#  24  Title_Rev            891 non-null    uint8
#  25  Title_Sir            891 non-null    uint8
#  26  Title_the Countess   891 non-null    uint8
#  27  Age_Category_5-10    891 non-null    uint8
#  28  Age_Category_10-15   891 non-null    uint8
#  29  Age_Category_15-20   891 non-null    uint8
#  30  Age_Category_20-25   891 non-null    uint8
#  31  Age_Category_25-30   891 non-null    uint8
#  32  Age_Category_30-35   891 non-null    uint8
#  33  Age_Category_35-40   891 non-null    uint8
#  34  Age_Category_40-50   891 non-null    uint8
#  35  Age_Category_50-60   891 non-null    uint8
#  36  Age_Category_60-70   891 non-null    uint8
#  37  Age_Category_70-100  891 non-null    uint8
#  38  Fare_bin_5-10        891 non-null    uint8
#  39  Fare_bin_10-15       891 non-null    uint8
#  40  Fare_bin_15-20       891 non-null    uint8
#  41  Fare_bin_20-25       891 non-null    uint8
#  42  Fare_bin_25-30       891 non-null    uint8
#  43  Fare_bin_30-40       891 non-null    uint8
#  44  Fare_bin_40-50       891 non-null    uint8
#  45  Fare_bin_50-65       891 non-null    uint8
#  46  Fare_bin_65-80       891 non-null    uint8
#  47  Fare_bin_80-100      891 non-null    uint8
#  48  Fare_bin_100-150     891 non-null    uint8
#  49  Fare_bin_150-200     891 non-null    uint8
#  50  Fare_bin_200-250     891 non-null    uint8
#  51  Fare_bin_250-300     891 non-null    uint8
#  52  Fare_bin_300+        891 non-null    uint8
#  53  Cabin_ind            891 non-null    int64
#  54  Deck                 891 non-null    object
# dtypes: float64(2), int64(6), object(4), uint8(43)
# memory usage: 121.1+ KB
# None

# %%
train_data = pd.get_dummies(train_data, columns=['Sex', 'Embarked', 'Deck'], drop_first=True, 
                            prefix={'Sex': 'Sex', 'Embarked': 'Embarked', 'Deck': 'Deck'})
test_data = pd.get_dummies(test_data, columns=['Sex', 'Embarked', 'Deck'], drop_first=True, 
                           prefix={'Sex': 'Sex', 'Embarked': 'Embarked', 'Deck': 'Deck'})

# %%
print(test_data['Ticket'])
# Out:
# 0                  330911
# 1                  363272
# 2                  240276
# 3                  315154
# 4                 3101298
#               ...
# 413             A.5. 3236
# 414              PC 17758
# 415    SOTON/O.Q. 3101262
# 416                359309
# 417                  2668
# Name: Ticket, Length: 418, dtype: object

# %%
train_data['Ticket_prefix'] = train_data['Ticket'].apply(lambda x: str(x)[0:2])
test_data['Ticket_prefix'] = test_data['Ticket'].apply(lambda x: str(x)[0:2])

# %%
Ticket_prefix_survival_rate = train_data.groupby('Ticket_prefix')['Survived'].mean()

print(Ticket_prefix_survival_rate)

plt.figure(figsize=(12, 6))
Ticket_prefix_survival_rate.sort_values().plot(kind='barh', color='skyblue')
plt.title('Survival Rate by Ticket')
plt.xlabel('Survival Rate')
plt.ylabel('Ticket')
plt.show()
# Out:
# Ticket_prefix
# 11    0.568182
# 12    0.500000
# 13    0.727273
# 14    0.750000
# 16    0.800000
# 17    0.769231
# 19    0.687500
# 20    1.000000
# 21    0.000000
# 22    0.666667
# 23    0.444444
# 24    0.551724
# 25    0.500000
# 26    0.416667
# 27    0.750000
# 28    0.166667
# 29    0.642857
# 31    0.243243
# 32    0.000000
# 33    0.562500
# 34    0.143939
# 35    0.296296
# 36    0.347826
# 37    0.240000
# 38    0.200000
# 39    0.600000
# 41    0.222222
# 45    0.000000
# 54    0.000000
# 57    0.000000
# 65    0.250000
# 69    0.000000
# 72    0.000000
# 75    0.125000
# 84    0.000000
# 92    1.000000
# A.    0.000000
# A/    0.083333
# A4    0.000000
# C     0.400000
# C.    0.464286
# CA    0.071429
# F.    0.666667
# Fa    0.000000
# LI    0.250000
# P/    0.500000
# PC    0.650000
# PP    0.666667
# S.    0.142857
# SC    0.500000
# SO    0.166667
# ST    0.444444
# SW    1.000000
# W.    0.100000
# W/    0.000000
# WE    0.500000
# Name: Survived, dtype: float64

# %%
train_data = pd.get_dummies(train_data, columns=['Ticket_prefix'], drop_first=True)

# %%
test_data = pd.get_dummies(test_data, columns=['Ticket_prefix'], drop_first=True)

# %%
train_data = pd.get_dummies(train_data, columns=['Pclass'], drop_first=True)

# %%
test_data = pd.get_dummies(test_data, columns=['Pclass'], drop_first=True)

# %%
print(test_data.info())
print(train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 100 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PassengerId          418 non-null    int64
#  1   Age                  418 non-null    float64
#  2   SibSp                418 non-null    int64
#  3   Parch                418 non-null    int64
#  4   Ticket               418 non-null    object
#  5   Fare                 418 non-null    float64
#  6   Title_Col            418 non-null    uint8
#  7   Title_Dona           418 non-null    uint8
#  8   Title_Dr             418 non-null    uint8
#  9   Title_Master         418 non-null    uint8
#  10  Title_Miss           418 non-null    uint8
#  11  Title_Mr             418 non-null    uint8
#  12  Title_Mrs            418 non-null    uint8
#  13  Title_Ms             418 non-null    uint8
#  14  Title_Rev            418 non-null    uint8
#  15  Age_Category_5-10    418 non-null    uint8
#  16  Age_Category_10-15   418 non-null    uint8
#  17  Age_Category_15-20   418 non-null    uint8
#  18  Age_Category_20-25   418 non-null    uint8
#  19  Age_Category_25-30   418 non-null    uint8
#  20  Age_Category_30-35   418 non-null    uint8
#  21  Age_Category_35-40   418 non-null    uint8
#  22  Age_Category_40-50   418 non-null    uint8
#  23  Age_Category_50-60   418 non-null    uint8
#  24  Age_Category_60-70   418 non-null    uint8
#  25  Age_Category_70-100  418 non-null    uint8
#  26  Fare_bin_5-10        418 non-null    uint8
#  27  Fare_bin_10-15       418 non-null    uint8
#  28  Fare_bin_15-20       418 non-null    uint8
#  29  Fare_bin_20-25       418 non-null    uint8
#  30  Fare_bin_25-30       418 non-null    uint8
#  31  Fare_bin_30-40       418 non-null    uint8
#  32  Fare_bin_40-50       418 non-null    uint8
#  33  Fare_bin_50-65       418 non-null    uint8
#  34  Fare_bin_65-80       418 non-null    uint8
#  35  Fare_bin_80-100      418 non-null    uint8
#  36  Fare_bin_100-150     418 non-null    uint8
#  37  Fare_bin_150-200     418 non-null    uint8
#  38  Fare_bin_200-250     418 non-null    uint8
#  39  Fare_bin_250-300     418 non-null    uint8
#  40  Fare_bin_300+        418 non-null    uint8
#  41  Cabin_ind            418 non-null    int64
#  42  Sex_male             418 non-null    uint8
#  43  Embarked_Q           418 non-null    uint8
#  44  Embarked_S           418 non-null    uint8
#  45  Deck_B               418 non-null    uint8
#  46  Deck_C               418 non-null    uint8
#  47  Deck_D               418 non-null    uint8
#  48  Deck_E               418 non-null    uint8
#  49  Deck_F               418 non-null    uint8
#  50  Deck_G               418 non-null    uint8
#  51  Deck_M               418 non-null    uint8
#  52  Ticket_prefix_12     418 non-null    uint8
#  53  Ticket_prefix_13     418 non-null    uint8
#  54  Ticket_prefix_16     418 non-null    uint8
#  55  Ticket_prefix_17     418 non-null    uint8
#  56  Ticket_prefix_19     418 non-null    uint8
#  57  Ticket_prefix_20     418 non-null    uint8
#  58  Ticket_prefix_21     418 non-null    uint8
#  59  Ticket_prefix_22     418 non-null    uint8
#  60  Ticket_prefix_23     418 non-null    uint8
#  61  Ticket_prefix_24     418 non-null    uint8
#  62  Ticket_prefix_25     418 non-null    uint8
#  63  Ticket_prefix_26     418 non-null    uint8
#  64  Ticket_prefix_28     418 non-null    uint8
#  65  Ticket_prefix_29     418 non-null    uint8
#  66  Ticket_prefix_31     418 non-null    uint8
#  67  Ticket_prefix_32     418 non-null    uint8
#  68  Ticket_prefix_33     418 non-null    uint8
#  69  Ticket_prefix_34     418 non-null    uint8
#  70  Ticket_prefix_35     418 non-null    uint8
#  71  Ticket_prefix_36     418 non-null    uint8
#  72  Ticket_prefix_37     418 non-null    uint8
#  73  Ticket_prefix_38     418 non-null    uint8
#  74  Ticket_prefix_39     418 non-null    uint8
#  75  Ticket_prefix_41     418 non-null    uint8
#  76  Ticket_prefix_65     418 non-null    uint8
#  77  Ticket_prefix_68     418 non-null    uint8
#  78  Ticket_prefix_69     418 non-null    uint8
#  79  Ticket_prefix_72     418 non-null    uint8
#  80  Ticket_prefix_75     418 non-null    uint8
#  81  Ticket_prefix_79     418 non-null    uint8
#  82  Ticket_prefix_92     418 non-null    uint8
#  83  Ticket_prefix_A.     418 non-null    uint8
#  84  Ticket_prefix_A/     418 non-null    uint8
#  85  Ticket_prefix_AQ     418 non-null    uint8
#  86  Ticket_prefix_C      418 non-null    uint8
#  87  Ticket_prefix_C.     418 non-null    uint8
#  88  Ticket_prefix_CA     418 non-null    uint8
#  89  Ticket_prefix_F.     418 non-null    uint8
#  90  Ticket_prefix_LP     418 non-null    uint8
#  91  Ticket_prefix_PC     418 non-null    uint8
#  92  Ticket_prefix_PP     418 non-null    uint8
#  93  Ticket_prefix_S.     418 non-null    uint8
#  94  Ticket_prefix_SC     418 non-null    uint8
#  95  Ticket_prefix_SO     418 non-null    uint8
#  96  Ticket_prefix_ST     418 non-null    uint8
#  97  Ticket_prefix_W.     418 non-null    uint8
#  98  Pclass_2             418 non-null    uint8
#  99  Pclass_3             418 non-null    uint8
# dtypes: float64(2), int64(4), object(1), uint8(93)
# memory usage: 60.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Columns: 119 entries, PassengerId to Pclass_3
# dtypes: float64(2), int64(5), object(1), uint8(111)
# memory usage: 152.4+ KB
# None

# %%
train_data.drop('Ticket', axis=1, inplace=True)
test_data.drop('Ticket', axis=1, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot survival rate by SibSp
sns.barplot(x='Parch', y='Survived', data=train_data)
plt.title('Survival Rate by SibSp')
plt.show()

# %%
train_data['Family_size'] = train_data['SibSp'] + train_data['Parch'] 
test_data['Family_size'] = test_data['SibSp'] + test_data['Parch']

# %%
plot_distribution('Family_size','Survived')

# %%
bins_Familysize = [0,1,3,5,15]
labels_Familysize = ['solo', 'Small','Medium','Large']

train_data['Familysize_Group'] = pd.cut(train_data['Family_size'], bins=bins_Familysize, labels=labels_Familysize , right=False)
test_data['Familysize_Group'] = pd.cut(train_data['Family_size'], bins=bins_Familysize, labels=labels_Familysize , right=False)

# %%
train_data = pd.get_dummies(train_data, columns=['Familysize_Group'], drop_first=True)

# %%
test_data = pd.get_dummies(test_data, columns=['Familysize_Group'], drop_first=True)

# %%
train_data.drop('Family_size', axis=1, inplace=True)
test_data.drop('Family_size', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 train_data.drop('Family_size', axis=1, inplace=True)
#       2 test_data.drop('Family_size', axis=1, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Family_size'] not found in axis"

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Columns: 102 entries, PassengerId to Familysize_Group_Large
# dtypes: float64(2), int64(4), uint8(96)
# memory usage: 58.9 KB

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both the training and test data
train_data[['Fare', 'Age']] = scaler.fit_transform(train_data[['Fare', 'Age']])
test_data[['Fare', 'Age']] = scaler.transform(test_data[['Fare', 'Age']])

# %%
X_train = train_data.drop(['Survived', 'PassengerId'], axis=1)

# %%
y_train = train_data['Survived']

# %%
X_test = test_data.drop(['PassengerId'], axis=1)

# %%
train_columns = set(X_train.columns)
test_columns = set(X_test.columns)

# %%
missing_cols_test = train_columns - test_columns

# %%
missing_cols_test
# Out:
# {'Deck_T',
#  'Ticket_prefix_14',
#  'Ticket_prefix_27',
#  'Ticket_prefix_45',
#  'Ticket_prefix_54',
#  'Ticket_prefix_57',
#  'Ticket_prefix_84',
#  'Ticket_prefix_A4',
#  'Ticket_prefix_Fa',
#  'Ticket_prefix_LI',
#  'Ticket_prefix_P/',
#  'Ticket_prefix_SW',
#  'Ticket_prefix_W/',
#  'Ticket_prefix_WE',
#  'Title_Capt',
#  'Title_Don',
#  'Title_Jonkheer',
#  'Title_Lady',
#  'Title_Major',
#  'Title_Mlle',
#  'Title_Mme',
#  'Title_Sir',
#  'Title_the Countess'}

# %%
for col in missing_cols_test:
    X_test[col] = 0

# %%
X_test = X_test[X_train.columns]

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Columns: 119 entries, Age to Familysize_Group_Large
# dtypes: float64(2), int64(26), uint8(91)
# memory usage: 128.7 KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Columns: 119 entries, Age to Familysize_Group_Large
# dtypes: float64(2), int64(3), uint8(114)
# memory usage: 134.1 KB

# %% [markdown]
# ## Construct Decision Trees

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
X_train.columns

# %%
X_train_split, X_val, y_train_split, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
print(X_train_split.isnull().sum().sum())  # Should be 0
print(y_train_split.isnull().sum())         # Should be 0

# Ensure correct types
print(type(X_train_split))  # Should be DataFrame or ndarray
print(type(y_train_split))  # Should be Series or ndarray

# Check dimensions
print(X_train_split.shape)  # Should be (n_samples, n_features)
print(y_train_split.shape)
# Out:
# 0
# 0
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (712, 119)
# (712,)

# %%
param_grid = {
    'n_estimators': [ 50, 75, 100, 200],
    'max_depth': [ 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.1, 0.3],
    'subsample': [0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]
}

# %%
print(y_train_split.value_counts())
# Out:
# 0    444
# 1    268
# Name: Survived, dtype: int64

# %%
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import StratifiedKFold, GridSearchCV
stratified_kf = StratifiedKFold(n_splits=5)

kf_random_search = RandomizedSearchCV(
    estimator=xgb.XGBClassifier(random_state=102),
    param_distributions=param_grid,
    n_iter=500,
    cv=stratified_kf,
    n_jobs=-1,
    scoring='accuracy',
    verbose=2,
    random_state=102,
    error_score='raise'
)

kf_random_search .fit(X_train_split, y_train_split)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#                    error_score='raise',
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, gr...
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            random_state=102, ...),
#                    n_iter=500, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.8, 0.9, 1.0],
#                                         'learning_rate': [0.01, 0.03, 0.1, 0.3],
#                                         'max_depth': [6, 7, 8, 9, 10],
#                                         'n_estimators': [50, 75, 100, 200],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=102, scoring='accuracy', verbose=2)

# %%
results = kf_random_search.cv_results_

results_df = pd.DataFrame({
    'mean_test_score': results['mean_test_score'],
    'std_test_score': results['std_test_score'],
    'params': results['params'],
    'rank_test_score': results['rank_test_score']
})

print("Best parameters:", kF_grid_search.best_params_)
print(results_df.sort_values(by='rank_test_score'))
# Out:
# Best parameters: {'colsample_bytree': 0.9, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 50, 'subsample': 0.7}
#      mean_test_score  std_test_score  \
# 111         0.841278        0.020203
# 367         0.838491        0.019251
# 85          0.838491        0.013186
# 140         0.838491        0.014651
# 382         0.838491        0.020739
# ..               ...             ...
# 39          0.796395        0.016620
# 460         0.796366        0.009545
# 284         0.794987        0.019610
# 495         0.793568        0.017204
# 190         0.792180        0.018115
#
#                                                 params  rank_test_score
# 111  {'subsample': 0.8, 'n_estimators': 50, 'max_de...                1
# 367  {'subsample': 0.7, 'n_estimators': 200, 'max_d...                2
# 85   {'subsample': 0.7, 'n_estimators': 50, 'max_de...                2
# 140  {'subsample': 1.0, 'n_estimators': 100, 'max_d...                2
# 382  {'subsample': 0.7, 'n_estimators': 75, 'max_de...                2
# ..                                                 ...              ...
# 39   {'subsample': 1.0, 'n_estimators': 100, 'max_d...              496
# 460  {'subsample': 0.7, 'n_estimators': 200, 'max_d...              497
# 284  {'subsample': 0.7, 'n_estimators': 200, 'max_d...              498
# 495  {'subsample': 1.0, 'n_estimators': 200, 'max_d...              499
# 190  {'subsample': 1.0, 'n_estimators': 200, 'max_d...              500
#
# [500 rows x 4 columns]

# %%
results_df['params'][85]
# Out:
# {'subsample': 0.7,
#  'n_estimators': 50,
#  'max_depth': 6,
#  'learning_rate': 0.03,
#  'colsample_bytree': 0.9}

# %%
grid_search = GridSearchCV(estimator=xgb.XGBClassifier(random_state=102), 
                           param_grid=param_grid, 
                           cv=3, 
                           n_jobs=-1, 
                           scoring='accuracy')

grid_search.fit(X_train_split, y_train_split)

print("Best parameters:", grid_search.best_params_)

results = grid_search.cv_results_

results_df = pd.DataFrame({
    'mean_test_score': results['mean_test_score'],
    'std_test_score': results['std_test_score'],
    'params': results['params'],
    'rank_test_score': results['rank_test_score']
})

print(results_df.sort_values(by='rank_test_score'))
# Out:
# Best parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.03, 'max_depth': 9, 'n_estimators': 50, 'subsample': 0.9}
#      mean_test_score  std_test_score  \
# 770         0.839922        0.022301
# 130         0.839911        0.020758
# 114         0.839905        0.017733
# 786         0.838522        0.023890
# 754         0.838522        0.023890
# ..               ...             ...
# 255         0.785129        0.012100
# 916         0.785117        0.005762
# 940         0.783717        0.009731
# 285         0.782346        0.022469
# 620         0.776696        0.008821
#
#                                                 params  rank_test_score
# 770  {'colsample_bytree': 1.0, 'learning_rate': 0.0...                1
# 130  {'colsample_bytree': 0.8, 'learning_rate': 0.0...                2
# 114  {'colsample_bytree': 0.8, 'learning_rate': 0.0...                3
# 786  {'colsample_bytree': 1.0, 'learning_rate': 0.0...                4
# 754  {'colsample_bytree': 1.0, 'learning_rate': 0.0...                4
# ..                                                 ...              ...
# 255  {'colsample_bytree': 0.8, 'learning_rate': 0.3...              956
# 916  {'colsample_bytree': 1.0, 'learning_rate': 0.3...              957
# 940  {'colsample_bytree': 1.0, 'learning_rate': 0.3...              958
# 285  {'colsample_bytree': 0.8, 'learning_rate': 0.3...              959
# 620  {'colsample_bytree': 0.9, 'learning_rate': 0.3...              960
#
# [960 rows x 4 columns]

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint

randomized_search = RandomizedSearchCV(
    estimator=xgb.XGBClassifier(random_state=102),
    param_distributions=param_grid,
    n_iter=300,  # Number of parameter settings sampled
    cv=5,
    n_jobs=-1,
    scoring='accuracy',
    random_state=44
)

randomized_search.fit(X_train_split, y_train_split)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            random_state=102, ...),
#                    n_iter=300, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.8, 0.9, 1.0],
#                                         'learning_rate': [0.01, 0.03, 0.1, 0.3],
#                                         'max_depth': [6, 7, 8, 9, 10],
#                                         'n_estimators': [50, 75, 100, 200],
#                                         'subsample': [0.7, 0.8, 0.9, 1.0]},
#                    random_state=44, scoring='accuracy')

# %%
results = randomized_search.cv_results_

results_df = pd.DataFrame({
    'mean_test_score': results['mean_test_score'],
    'std_test_score': results['std_test_score'],
    'params': results['params'],
    'rank_test_score': results['rank_test_score']
})

print(results_df.sort_values(by='rank_test_score'))
# Out:
#      mean_test_score  std_test_score  \
# 149         0.839890        0.019529
# 297         0.839860        0.022106
# 282         0.838491        0.014651
# 287         0.838491        0.013186
# 158         0.838491        0.018191
# ..               ...             ...
# 115         0.796395        0.028829
# 50          0.796366        0.009545
# 160         0.794977        0.026958
# 173         0.794957        0.014795
# 131         0.793568        0.017204
#
#                                                 params  rank_test_score
# 149  {'subsample': 0.7, 'n_estimators': 50, 'max_de...                1
# 297  {'subsample': 0.9, 'n_estimators': 50, 'max_de...                2
# 282  {'subsample': 1.0, 'n_estimators': 100, 'max_d...                3
# 287  {'subsample': 0.7, 'n_estimators': 50, 'max_de...                3
# 158  {'subsample': 0.9, 'n_estimators': 50, 'max_de...                3
# ..                                                 ...              ...
# 115  {'subsample': 1.0, 'n_estimators': 200, 'max_d...              295
# 50   {'subsample': 0.7, 'n_estimators': 200, 'max_d...              297
# 160  {'subsample': 1.0, 'n_estimators': 200, 'max_d...              298
# 173  {'subsample': 0.7, 'n_estimators': 200, 'max_d...              299
# 131  {'subsample': 1.0, 'n_estimators': 200, 'max_d...              300
#
# [300 rows x 4 columns]

# %%
print("Best parameters:", randomized_search.best_params_)
# Out:
# Best parameters: {'subsample': 0.7, 'n_estimators': 50, 'max_depth': 7, 'learning_rate': 0.03, 'colsample_bytree': 1.0}

# %%
final_model = xgb.XGBClassifier(
    n_estimators=50,
    max_depth=6,
    learning_rate=0.03,
    colsample_bytree=0.9,
    subsample=0.7,
    random_state=102
)

# %%
final_model.fit(X_train_split,y_train_split)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.03, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, random_state=102, ...)

# %%
import matplotlib.pyplot as plt
feature_importances = final_model.feature_importances_

# Create a DataFrame for better visualization
features = X_train.columns
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
})

# Sort the DataFrame by importance
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(25, 25))
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances in XGBoost')
plt.gca().invert_yaxis()
plt.show()

# %%
final_model.fit(X_train_split,y_train_split)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.03, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, random_state=102, ...)

# %%
y_pred = final_model.predict(X_val)

# %%
accuracy = accuracy_score(y_val, y_pred)

# %%
cv_scores = cross_val_score(final_model, X_train, y_train, cv=5, scoring='accuracy')

# Print cross-validation scores
print("Cross-validation Scores:")
print(cv_scores)

# Print mean and standard deviation of the cross-validation scores
print(f"Mean Accuracy: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
# Out:
# Cross-validation Scores:
# [0.84916201 0.81460674 0.85393258 0.80337079 0.83707865]
# Mean Accuracy: 0.8316
# Standard Deviation: 0.0196

# %%
final_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.03, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, random_state=102, ...)

# %%
print(X_train.dtypes)
print(X_test.dtypes)
# Out:
# Age                        float64
# SibSp                        int64
# Parch                        int64
# Fare                       float64
# Title_Capt                   uint8
#                             ...
# Pclass_2                     uint8
# Pclass_3                     uint8
# Familysize_Group_Small       uint8
# Familysize_Group_Medium      uint8
# Familysize_Group_Large       uint8
# Length: 119, dtype: object
# Age                        float64
# SibSp                        int64
# Parch                        int64
# Fare                       float64
# Title_Capt                   int64
#                             ...
# Pclass_2                     uint8
# Pclass_3                     uint8
# Familysize_Group_Small       uint8
# Familysize_Group_Medium      uint8
# Familysize_Group_Large       uint8
# Length: 119, dtype: object

# %%
predictions = final_model.predict(X_test)

# %%
 results = pd.DataFrame({
     'PassengerId': test_data['PassengerId'],
     'Survived': predictions
    })

# %%
output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('prediction12.csv', index=False)

# %%
results_df.sort_values(by='rank_test_score').head(5)
# Out:
#      mean_test_score  std_test_score  \
# 111         0.841278        0.020203
# 367         0.838491        0.019251
# 85          0.838491        0.013186
# 140         0.838491        0.014651
# 382         0.838491        0.020739
#
#                                                 params  rank_test_score
# 111  {'subsample': 0.8, 'n_estimators': 50, 'max_de...                1
# 367  {'subsample': 0.7, 'n_estimators': 200, 'max_d...                2
# 85   {'subsample': 0.7, 'n_estimators': 50, 'max_de...                2
# 140  {'subsample': 1.0, 'n_estimators': 100, 'max_d...                2
# 382  {'subsample': 0.7, 'n_estimators': 75, 'max_de...                2

# %%
top_5_params =results_df.sort_values(by='rank_test_score').head(5)['params'].tolist()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

base_models = [
    (f'xgb_model_{i}', XGBClassifier(**params, random_state=102))
    for i, params in enumerate(top_5_params)
]

# %%
meta_model = LogisticRegression()

# %%
from sklearn.ensemble import StackingClassifier

stacking_model = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5)

stacking_model.fit(X_train_split, y_train_split)

accuracy = stacking_model.score(X_val, y_val)

# %%
accuracy
# Out:
# 0.8212290502793296

# %%
stacking_model.fit(X_train, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('xgb_model_0',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=0.8, device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None, gamma=None,
#                                               grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=No...
#                                               importance_type=None,
#                                               interaction_constraints=None,
#                                               learning_rate=0.03, max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None, max_depth=6,
#                                               max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=100, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               random_state=102, ...))],
#                    final_estimator=LogisticRegression())

# %%
predictions = stacking_model.predict(X_test)

# %%
 results = pd.DataFrame({
     'PassengerId': test_data['PassengerId'],
     'Survived': predictions
    })

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 76 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Pclass                 891 non-null    int64
#  1   Age                    891 non-null    float64
#  2   SibSp                  891 non-null    int64
#  3   Parch                  891 non-null    int64
#  4   Fare                   891 non-null    float64
#  5   Age_Category_Child     891 non-null    uint8
#  6   Age_Category_Teenager  891 non-null    uint8
#  7   Age_Category_Adult     891 non-null    uint8
#  8   Age_Category_Senior    891 non-null    uint8
#  9   Cabin_ind              891 non-null    int64
#  10  Sex_male               891 non-null    uint8
#  11  Embarked_Q             891 non-null    uint8
#  12  Embarked_S             891 non-null    uint8
#  13  Deck_B                 891 non-null    uint8
#  14  Deck_C                 891 non-null    uint8
#  15  Deck_D                 891 non-null    uint8
#  16  Deck_E                 891 non-null    uint8
#  17  Deck_F                 891 non-null    uint8
#  18  Deck_G                 891 non-null    uint8
#  19  Deck_M                 891 non-null    uint8
#  20  Deck_T                 891 non-null    uint8
#  21  Ticket_prefix_12       891 non-null    uint8
#  22  Ticket_prefix_13       891 non-null    uint8
#  23  Ticket_prefix_14       891 non-null    uint8
#  24  Ticket_prefix_16       891 non-null    uint8
#  25  Ticket_prefix_17       891 non-null    uint8
#  26  Ticket_prefix_19       891 non-null    uint8
#  27  Ticket_prefix_20       891 non-null    uint8
#  28  Ticket_prefix_21       891 non-null    uint8
#  29  Ticket_prefix_22       891 non-null    uint8
#  30  Ticket_prefix_23       891 non-null    uint8
#  31  Ticket_prefix_24       891 non-null    uint8
#  32  Ticket_prefix_25       891 non-null    uint8
#  33  Ticket_prefix_26       891 non-null    uint8
#  34  Ticket_prefix_27       891 non-null    uint8
#  35  Ticket_prefix_28       891 non-null    uint8
#  36  Ticket_prefix_29       891 non-null    uint8
#  37  Ticket_prefix_31       891 non-null    uint8
#  38  Ticket_prefix_32       891 non-null    uint8
#  39  Ticket_prefix_33       891 non-null    uint8
#  40  Ticket_prefix_34       891 non-null    uint8
#  41  Ticket_prefix_35       891 non-null    uint8
#  42  Ticket_prefix_36       891 non-null    uint8
#  43  Ticket_prefix_37       891 non-null    uint8
#  44  Ticket_prefix_38       891 non-null    uint8
#  45  Ticket_prefix_39       891 non-null    uint8
#  46  Ticket_prefix_41       891 non-null    uint8
#  47  Ticket_prefix_45       891 non-null    uint8
#  48  Ticket_prefix_54       891 non-null    uint8
#  49  Ticket_prefix_57       891 non-null    uint8
#  50  Ticket_prefix_65       891 non-null    uint8
#  51  Ticket_prefix_69       891 non-null    uint8
#  52  Ticket_prefix_72       891 non-null    uint8
#  53  Ticket_prefix_75       891 non-null    uint8
#  54  Ticket_prefix_84       891 non-null    uint8
#  55  Ticket_prefix_92       891 non-null    uint8
#  56  Ticket_prefix_A.       891 non-null    uint8
#  57  Ticket_prefix_A/       891 non-null    uint8
#  58  Ticket_prefix_A4       891 non-null    uint8
#  59  Ticket_prefix_C        891 non-null    uint8
#  60  Ticket_prefix_C.       891 non-null    uint8
#  61  Ticket_prefix_CA       891 non-null    uint8
#  62  Ticket_prefix_F.       891 non-null    uint8
#  63  Ticket_prefix_Fa       891 non-null    uint8
#  64  Ticket_prefix_LI       891 non-null    uint8
#  65  Ticket_prefix_P/       891 non-null    uint8
#  66  Ticket_prefix_PC       891 non-null    uint8
#  67  Ticket_prefix_PP       891 non-null    uint8
#  68  Ticket_prefix_S.       891 non-null    uint8
#  69  Ticket_prefix_SC       891 non-null    uint8
#  70  Ticket_prefix_SO       891 non-null    uint8
#  71  Ticket_prefix_ST       891 non-null    uint8
#  72  Ticket_prefix_SW       891 non-null    uint8
#  73  Ticket_prefix_W.       891 non-null    uint8
#  74  Ticket_prefix_W/       891 non-null    uint8
#  75  Ticket_prefix_WE       891 non-null    uint8
# dtypes: float64(2), int64(4), uint8(70)
# memory usage: 102.8 KB

# %%
output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('prediction2.csv', index=False)

# %%
from sklearn.ensemble import RandomForestClassifier

param_grid = {
    'n_estimators': [30, 40, 50, 75, 100, 200],
    'max_depth': [5, 6, 7, 8, 9, 10, 12, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None, 0.5, 0.7],
    'bootstrap': [True, False]
}

rf_model = RandomForestClassifier(random_state=102)

grid_search = GridSearchCV(estimator=rf_model, 
                           param_grid=param_grid, 
                           cv=5, 
                           n_jobs=-1, 
                           scoring='accuracy')

grid_search.fit(X_train_split, y_train_split)

print("Best parameters:", grid_search.best_params_)

RF_results = grid_search.cv_results_

results_df = pd.DataFrame({
    'mean_test_score': RF_results['mean_test_score'],
    'std_test_score': RF_results['std_test_score'],
    'params': RF_results['params'],
    'rank_test_score': RF_results['rank_test_score']
})

print(results_df.sort_values(by='rank_test_score'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[171], line 20
#      12 rf_model = RandomForestClassifier(random_state=102)
#      14 grid_search = GridSearchCV(estimator=rf_model,
#      15                            param_grid=param_grid,
#      16                            cv=5,
#      17                            n_jobs=-1,
#      18                            scoring='accuracy')
# ---> 20 grid_search.fit(X_train_split, y_train_split)
#      22 print("Best parameters:", grid_search.best_params_)
#      24 RF_results = grid_search.cv_results_
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~\AppData\Local\Programs\Python\Python39\lib\concurrent\futures\_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)
rfe = RFE(model, n_features_to_select=40)
fit = rfe.fit(X_train, y_train)

selected_features = X_train.columns[fit.support_]
print("Selected features:", selected_features)
# Out:
# Selected features: Index(['Age', 'SibSp', 'Parch', 'Fare', 'Title_Master', 'Title_Miss',
#        'Title_Mr', 'Title_Mrs', 'Age_Category_12-20', 'Age_Category_20-30',
#        'Age_Category_30-40', 'Age_Category_40-50', 'Fare_bin_10-20',
#        'Fare_bin_20-30', 'Fare_bin_30-40', 'Fare_bin_50-100', 'Cabin_ind',
#        'Sex_male', 'Embarked_Q', 'Embarked_S', 'Deck_B', 'Deck_C', 'Deck_D',
#        'Deck_E', 'Deck_M', 'Ticket_prefix_16', 'Ticket_prefix_19',
#        'Ticket_prefix_24', 'Ticket_prefix_26', 'Ticket_prefix_31',
#        'Ticket_prefix_34', 'Ticket_prefix_35', 'Ticket_prefix_36',
#        'Ticket_prefix_38', 'Ticket_prefix_A/', 'Ticket_prefix_PC',
#        'Ticket_prefix_ST', 'Pclass_2', 'Pclass_3', 'Alone'],
#       dtype='object')

# %%
importances = model.feature_importances_
feature_names = X_train.columns
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 importances = model.feature_importances_
#       2 feature_names = X_train.columns
#       3 importance_df = pd.DataFrame({
#       4     'Feature': feature_names,
#       5     'Importance': importances
#       6 }).sort_values(by='Importance', ascending=False)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:628, in BaseForest.feature_importances_(self)
#     607 @property
#     608 def feature_importances_(self):
#     609     """
#     610     The impurity-based feature importances.
#     611
#    (...)
#     626         array of zeros.
#     627     """
# --> 628     check_is_fitted(self)
#     630     all_importances = Parallel(n_jobs=self.n_jobs, prefer="threads")(
#     631         delayed(getattr)(tree, "feature_importances_")
#     632         for tree in self.estimators_
#     633         if tree.tree_.node_count > 1
#     634     )
#     636     if not all_importances:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:1390, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1385     fitted = [
#    1386         v for v in vars(estimator) if v.endswith("_") and not v.startswith("__")
#    1387     ]
#    1389 if not fitted:
# -> 1390     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This RandomForestClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
final_model = RandomForestClassifier(
    bootstrap=False,
    max_depth=9,
    min_samples_leaf=2,
    min_samples_split=5,
    n_estimators=40,
    max_features='sqrt',
    random_state=102
)

# %%
final_model.fit(X_train_split, y_train_split)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=9, min_samples_leaf=2,
#                        min_samples_split=5, n_estimators=40, random_state=102)

# %%
y_pred = final_model.predict(X_val)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy on validation set:", accuracy_score(y_val, y_pred))
print("Classification Report:\n", classification_report(y_val, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_val, y_pred))
# Out:
# Accuracy on validation set: 0.8435754189944135
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87       105
#            1       0.83      0.78      0.81        74
#
#     accuracy                           0.84       179
#    macro avg       0.84      0.83      0.84       179
# weighted avg       0.84      0.84      0.84       179
#
# Confusion Matrix:
#  [[93 12]
#  [16 58]]

# %%
final_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=9, min_samples_leaf=2,
#                        min_samples_split=5, n_estimators=40, random_state=102)

# %%
predictions = final_model.predict(X_test)

# %%
 results = pd.DataFrame({
     'PassengerId': test_data['PassengerId'],
     'Survived': predictions
    })
output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('prediction7.csv', index=False)

# %%
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.327751
# std     120.810458    0.469956
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.322967
# std     120.810458    0.468170
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000
